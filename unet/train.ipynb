# %%
from model import *
from data import *
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %% [markdown]
# --- Train ---

# %%
EPOCHs = 60
steps = 200
train_batch_size = 16
val_batch_size = 16

root_path = "synthetic_image/"

aug_args = dict( #define ImageDataGenerator parameters
    rotation_range = 0.2,
    width_shift_range = 0.05,
    height_shift_range = 0.05,
    shear_range = 0.05,
    zoom_range = 0.05,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

val_args =dict( #define ImageDataGenerator parameters
    rotation_range = 0.2,
    width_shift_range = 0.05,
    height_shift_range = 0.05,
    shear_range = 0.05,
    zoom_range = 0.05,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

image_folder= root_path

train_gene = trainGenerator(batch_size=train_batch_size,aug_dict=aug_args,train_path=image_folder,
                        image_folder='trainCT',label_folder='trainLabel',
                        image_color_mode='grayscale',label_color_mode='grayscale',
                        image_save_prefix=None,label_save_prefix=None,
                        flag_multi_class=True,save_to_dir=None
                        )
val_gene = valGenerator(batch_size=val_batch_size,aug_dict=val_args,train_path=image_folder,
                        image_folder='valCT',label_folder='valLabel',
                        image_color_mode='grayscale',label_color_mode='grayscale',
                        image_save_prefix=None,label_save_prefix=None,
                        flag_multi_class=True,save_to_dir=None
                        )

model = unet(num_class=11)
lrate = LearningRateScheduler(step_decay)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=10, mode='auto')

model_checkpoint = ModelCheckpoint('bone.hdf5',monitor='val_loss',verbose=1,save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss',patience=10,verbose=0) 

H = model.fit_generator(train_gene,
                              steps_per_epoch=steps,
                              epochs=EPOCHs,
                              verbose=1,
                              validation_data = val_gene,
                              validation_steps=15,
                              shuffle = True,
                              callbacks=[model_checkpoint]
                              )

# %%
N = EPOCHs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history['val_loss'], label="val_loss")

plt.title("Training/Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["dice_coef"], label="train_dice")
plt.plot(np.arange(0, N), H.history['val_dice_coef'], label="val_dice")

plt.title("Training/Validation Dice coef")
plt.xlabel("Epoch")
plt.ylabel("Dice Coef")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["lr"], label="learning rate")

plt.title("Learning rate")
plt.xlabel("Epoch")
plt.ylabel("lr")
plt.legend(loc="lower left")

# %% [markdown]
# --- Test ---

# %%
numtestImage = 1
num_class =11

testCTPath = "synthetic_image/testCT"
testLabelPath = "synthetic_image/testLabel"
savePath = "synthetic_image/real_result/origin"

testGene = testGenerator(testCTPath,numtestImage)

generatedModel = load_model('model/origin.hdf5',custom_objects={'dice_coef_loss':dice_coef_loss,'dice_coef':dice_coef})

results = generatedModel.predict(testGene,verbose=1)
saveResult(savePath,results)


prediction = createData(savePath,'predict',numtestImage,'.tif')

groundTruth = createData(testLabelPath,None,numtestImage,'.png')


total = []
boneDice = []
for i in range(numtestImage):
    DiceScore = dice_coef(prediction[i],groundTruth[i])   
    for j in range(num_class-1):
        # use narray.copy() to copy the data itself rather than the address
        boneScore=boneDiceCalculator(prediction[i].copy(),groundTruth[i].copy(),j)
        boneDice.append(boneScore)
    boneIndex = boneDice.index(max(boneDice))
    print('The best prediction is the %dth bone'%(boneIndex+1))
    boneDice = []
    Diceinfo = DiceScore.numpy()
    Iouinfo = iou(float(Diceinfo))
    total.append(Diceinfo)
    print('Dice score for %dth image: %s\n'%(i+1,Diceinfo))

print('\nThe average dice score is %s'%(sum(total)/numtestImage))
# Out:
# 20/20 [==============================] - 13s 657ms/step
# ---Dice score for 1th bone: 0.9176863181988678
# ---Dice score for 2th bone: 0.8801123398770916
# ---Dice score for 3th bone: 0.718259990153055
# ---Dice score for 4th bone: 0.7794639975281044
# ---Dice score for 5th bone: 0.2728226682112905
# ---Dice score for 6th bone: 0.5836653410950635
# ---Dice score for 7th bone: 0.6214028789850442
# ---Dice score for 8th bone: 0.8797653960487174
# ---Dice score for 9th bone: 0.8854415285230541
# ---Dice score for 10th bone: 0.8416969699656562
# The best prediction is the 1th bone
# Dice score for 1th image: 0.9197979380903744
#
# ---Dice score for 1th bone: 0.9066070542165557
# ---Dice score for 2th bone: 0.9018502203046801
# ---Dice score for 3th bone: 0.8677007300411009
# ---Dice score for 4th bone: 0.4014598574273265
# ---Dice score for 5th bone: 0.8776185231225276
# ---Dice score for 6th bone: 0.9507278837016062
# ---Dice score for 7th bone: 0.8646575348073334
# ---Dice score for 8th bone: 0.9232623545210724
# ---Dice score for 9th bone: 0.8764007368859633
# ---Dice score for 10th bone: 0.858765341909369
# The best prediction is the 6th bone
# Dice score for 2th image: 0.9092846165738164
#
# ---Dice score for 1th bone: 0.9115685706759057
# ---Dice score for 2th bone: 0.8837958818748781
# ---Dice score for 3th bone: 0.6402408432915574
# ---Dice score for 4th bone: 0.7575562702182524
# ---Dice score for 5th bone: 0.18412162428003165
# ---Dice score for 6th bone: 0.41592920735655275
# ---Dice score for 7th bone: 0.6092307705295722
# ---Dice score for 8th bone: 0.8825174826612822
# ---Dice score for 9th bone: 0.9276057573967026
# ---Dice score for 10th bone: 0.8340877440359349
# The best prediction is the 9th bone
# Dice score for 3th image: 0.9083825839745644
#
# ---Dice score for 1th bone: 0.8840613932331632
# ---Dice score for 2th bone: 0.7913741224484931
# ---Dice score for 3th bone: 0.4198062438626344
# ---Dice score for 4th bone: 0.6158559941019305
# ---Dice score for 5th bone: 0.4932735438532273
# ---Dice score for 6th bone: 0.7303675060679454
# ---Dice score for 7th bone: 0.6428571437501697
# ---Dice score for 8th bone: 0.9338974088702021
# ---Dice score for 9th bone: 0.9489783728535345
# ---Dice score for 10th bone: 0.9384506042141282
# The best prediction is the 9th bone
# Dice score for 4th image: 0.9179869413937529
#
# ---Dice score for 1th bone: 0.9191616766977697
# ---Dice score for 2th bone: 0.8882607250184195
# ---Dice score for 3th bone: 0.8928571429863128
# ---Dice score for 4th bone: 2.0556319371282507e-08
# ---Dice score for 5th bone: 0.9558043607368893
# ---Dice score for 6th bone: 0.9504327302873393
# ---Dice score for 7th bone: 0.8628628633818588
# ---Dice score for 8th bone: 0.9514409791768588
# ---Dice score for 9th bone: 0.9717666598852271
# ---Dice score for 10th bone: 0.9342410414738685
# The best prediction is the 9th bone
# Dice score for 5th image: 0.8935581858927993
#
# ---Dice score for 1th bone: 0.8314503113898646
# ---Dice score for 2th bone: 0.7379737610443715
# ---Dice score for 3th bone: 0.15587680804254936
# ---Dice score for 4th bone: 0.5404509286200081
# ---Dice score for 5th bone: 0.4661851622189044
# ---Dice score for 6th bone: 0.6944219901416031
# ---Dice score for 7th bone: 0.660593793038596
# ---Dice score for 8th bone: 0.9005877844421194
# ---Dice score for 9th bone: 0.9727091995824572
# ---Dice score for 10th bone: 0.9311990602426826
# The best prediction is the 9th bone
# Dice score for 6th image: 0.9011408579500544
#
# ---Dice score for 1th bone: 0.9409067753883196
# ---Dice score for 2th bone: 0.9192339717294942
# ---Dice score for 3th bone: 0.8971553611921324
# ---Dice score for 4th bone: 0.9394952873501141
# ---Dice score for 5th bone: 0.7492113572298986
# ---Dice score for 6th bone: 0.6504854469160807
# ---Dice score for 7th bone: 0.9170600136976216
# ---Dice score for 8th bone: 0.9367488932106678
# ---Dice score for 9th bone: 0.9651465236079659
# ---Dice score for 10th bone: 0.891074890664742
# The best prediction is the 9th bone
# Dice score for 7th image: 0.9260641697074422
#
# ---Dice score for 1th bone: 1.2462810816737722e-08
# ---Dice score for 2th bone: 0.7026455033798508
# ---Dice score for 3th bone: 0.8409321178325182
# ---Dice score for 4th bone: 0.9291166848720664
# ---Dice score for 5th bone: 3.857860970406349e-06
# ---Dice score for 6th bone: 2.9536774761416703e-06
# ---Dice score for 7th bone: 0.8102189798479528
# ---Dice score for 8th bone: 0.9049723758284504
# ---Dice score for 9th bone: 1.2772680768557746e-06
# ---Dice score for 10th bone: 0.9002260254112208
# The best prediction is the 4th bone
# Dice score for 8th image: 0.8976996534415059
#
# ---Dice score for 1th bone: 0.9354435652605911
# ---Dice score for 2th bone: 0.9207890744111868
# ---Dice score for 3th bone: 0.7934990443502495
# ---Dice score for 4th bone: 0.9372579396196827
# ---Dice score for 5th bone: 0.8571428575707494
# ---Dice score for 6th bone: 0.6196581292599191
# ---Dice score for 7th bone: 0.9471057886227326
# ---Dice score for 8th bone: 0.9315985131446751
# ---Dice score for 9th bone: 0.8358606032873265
# ---Dice score for 10th bone: 0.9263833994004746
# The best prediction is the 7th bone
# Dice score for 9th image: 0.913056862377517
#
# ---Dice score for 1th bone: 0.2395118238925414
# ---Dice score for 2th bone: 0.07992388406018291
# ---Dice score for 3th bone: 0.01253482024140937
# ---Dice score for 4th bone: 0.6220022841989107
# ---Dice score for 5th bone: 0.42286609414762016
# ---Dice score for 6th bone: 6.150309593361765e-09
# ---Dice score for 7th bone: 0.6143057544409574
# ---Dice score for 8th bone: 0.0968241691489443
# ---Dice score for 9th bone: 1.7713260258222846e-08
# ---Dice score for 10th bone: 0.33240017887465156
# The best prediction is the 4th bone
# Dice score for 10th image: 0.869873585395918
#
# ---Dice score for 1th bone: 0.48119233553314233
# ---Dice score for 2th bone: 0.4645201629414475
# ---Dice score for 3th bone: 0.8368007398559895
# ---Dice score for 4th bone: 0.9613761765856349
# ---Dice score for 5th bone: 1.0
# ---Dice score for 6th bone: 0.7849910676237496
# ---Dice score for 7th bone: 0.6622009593820536
# ---Dice score for 8th bone: 0.9070305274024474
# ---Dice score for 9th bone: 0.8640033132740768
# ---Dice score for 10th bone: 0.8717268812308789
# The best prediction is the 5th bone
# Dice score for 11th image: 0.9018455310397462
#
# ---Dice score for 1th bone: 0.9014501332616411
# ---Dice score for 2th bone: 0.9124300112439796
# ---Dice score for 3th bone: 0.7002680968185527
# ---Dice score for 4th bone: 0.6833268256519844
# ---Dice score for 5th bone: 0.04242424802152783
# ---Dice score for 6th bone: 0.5708955255408954
# ---Dice score for 7th bone: 0.6041117569812777
# ---Dice score for 8th bone: 0.8732394368280499
# ---Dice score for 9th bone: 0.9336099591571629
# ---Dice score for 10th bone: 0.8290811778403191
# The best prediction is the 9th bone
# Dice score for 12th image: 0.9101839771052652
#
# ---Dice score for 1th bone: 0.7054758109702105
# ---Dice score for 2th bone: 0.7394037067861682
# ---Dice score for 3th bone: 0.7005695689853666
# ---Dice score for 4th bone: 0.9429657794876098
# ---Dice score for 5th bone: 1.1413833755981892e-08
# ---Dice score for 6th bone: 0.8269643632650802
# ---Dice score for 7th bone: 0.6309355913449258
# ---Dice score for 8th bone: 0.8537660257948466
# ---Dice score for 9th bone: 0.7624376245617656
# ---Dice score for 10th bone: 0.85370662480762
# The best prediction is the 4th bone
# Dice score for 13th image: 0.9186082695684402
#
# ---Dice score for 1th bone: 0.39221710281372246
# ---Dice score for 2th bone: 0.7690209982380838
# ---Dice score for 3th bone: 0.49542682999529314
# ---Dice score for 4th bone: 0.3455368165456417
# ---Dice score for 5th bone: 4.933345056934527e-09
# ---Dice score for 6th bone: 1.92109667878693e-08
# ---Dice score for 7th bone: 0.22552329902508877
# ---Dice score for 8th bone: 0.6125907996471807
# ---Dice score for 9th bone: 0.1694238560331377
# ---Dice score for 10th bone: 0.5929101029368063
# The best prediction is the 2th bone
# Dice score for 14th image: 0.7232783638154101
#
# ---Dice score for 1th bone: 0.10526316451822518
# ---Dice score for 2th bone: 0.6436629069884613
# ---Dice score for 3th bone: 0.8639926234472581
# ---Dice score for 4th bone: 0.9400286944314754
# ---Dice score for 5th bone: 0.9087523280745086
# ---Dice score for 6th bone: 1.1814605214966742e-05
# ---Dice score for 7th bone: 0.7247627282840287
# ---Dice score for 8th bone: 0.8710865562940928
# ---Dice score for 9th bone: 2.6254919515544227e-06
# ---Dice score for 10th bone: 0.867482934530652
# The best prediction is the 4th bone
# Dice score for 15th image: 0.8894533230048948
#
# ---Dice score for 1th bone: 0.6262482172267995
# ---Dice score for 2th bone: 0.7201806611892909
# ---Dice score for 3th bone: 0.7844282240425829
# ---Dice score for 4th bone: 0.961538461558734
# ---Dice score for 5th bone: 1.0
# ---Dice score for 6th bone: 0.9204819284654504
# ---Dice score for 7th bone: 0.5104808900748876
# ---Dice score for 8th bone: 0.7695805965664305
# ---Dice score for 9th bone: 0.9167567576073493
# ---Dice score for 10th bone: 0.8790030432213751
# The best prediction is the 5th bone
# Dice score for 16th image: 0.9253954149533355
# ---Dice score for 1th bone: 0.8883442266693344
# ---Dice score for 2th bone: 0.8758017493274735
# ---Dice score for 3th bone: 0.7267541360619126
# ---Dice score for 4th bone: 0.7852298418747291
# ---Dice score for 5th bone: 0.004987535958397206
# ---Dice score for 6th bone: 0.08745248173147914
# ---Dice score for 7th bone: 0.6578073100446298
# ---Dice score for 8th bone: 0.8796450362262851
# ---Dice score for 9th bone: 0.8514461014505929
# ---Dice score for 10th bone: 0.8927093738231938
# The best prediction is the 10th bone
# Dice score for 17th image: 0.924544813705136
#
# ---Dice score for 1th bone: 0.9103407053989316
# ---Dice score for 2th bone: 0.8898385565662612
# ---Dice score for 3th bone: 0.8918073797401644
# ---Dice score for 4th bone: 1.407459713823187e-08
# ---Dice score for 5th bone: 0.8489208640082069
# ---Dice score for 6th bone: 0.9415254240215518
# ---Dice score for 7th bone: 0.9018645734749975
# ---Dice score for 8th bone: 0.9108527134806926
# ---Dice score for 9th bone: 0.7842665081668362
# ---Dice score for 10th bone: 0.8250769071469273
# The best prediction is the 6th bone
# Dice score for 18th image: 0.8724660910788238
#
# ---Dice score for 1th bone: 0.6306203759507772
# ---Dice score for 2th bone: 0.6756756758723754
# ---Dice score for 3th bone: 0.6693877555271945
# ---Dice score for 4th bone: 0.7564053538740203
# ---Dice score for 5th bone: 0.212048195212707
# ---Dice score for 6th bone: 0.2185223821362733
# ---Dice score for 7th bone: 0.8046920829776003
# ---Dice score for 8th bone: 0.8477528092133286
# ---Dice score for 9th bone: 0.9123654742239223
# ---Dice score for 10th bone: 0.9029523315266147
# The best prediction is the 9th bone
# Dice score for 19th image: 0.8784719420938562
#
# ---Dice score for 1th bone: 0.7326679257592703
# ---Dice score for 2th bone: 0.2191570895190138
# ---Dice score for 3th bone: 0.2283950632290231
# ---Dice score for 4th bone: 0.4680468054284969
# ---Dice score for 5th bone: 0.9436464089598924
# ---Dice score for 6th bone: 0.5701657486620895
# ---Dice score for 7th bone: 0.11827957706136898
# ---Dice score for 8th bone: 0.21574973475522796
# ---Dice score for 9th bone: 0.7464443383969548
# ---Dice score for 10th bone: 0.7594171027018424
# The best prediction is the 5th bone
# Dice score for 20th image: 0.8354893123181248
#
#
# The average dice score is 0.8918291216740389

# %% [markdown]
# Load model

# %%
root_path = "synthetic_image/"
realGene = testGeneratorRealXRay(root_path+"realX-ray",8)

generatedModel = load_model('model/origin.hdf5',custom_objects={'dice_coef_loss':dice_coef_loss,'dice_coef':dice_coef})
results = generatedModel.predict(realGene,verbose=1)

saveResult(root_path+"real_result/origin/",results)
# Out:
# 8/8 [==============================] - 7s 833ms/step
